# %%
# des info head
# סעיפים 2 מכל אחד מעמוד 2 סה"כ 4 ואמריקאי
# 2.2 לספור שמית

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
Items = pd.read_csv("https://raw.githubusercontent.com/pythonai250824/14.05.2025/main/Items.csv")
Items
# Out:
#     id            item_name                   item_category  item_price  \
# 0   26        Action Camera           Photography Equipment     2694.25
# 1   37   Antivirus Software                        Software     4186.62
# 2   11       Blu-Ray Player     Video Players and Recorders     3382.86
# 3   25            Camcorder           Photography Equipment      860.01
# 4    7               Camera           Photography Equipment     2366.72
# 5   48               Camera           Photography Equipment     2039.08
# 6   28               Camera                             NaN      695.71
# 7   18     Computer Monitor       Computers and Accessories     4076.35
# 8   27          Dash Camera           Photography Equipment     1283.99
# 9    3              Desktop       Computers and Accessories     1121.84
# 10  44              Desktop       Computers and Accessories      723.59
# 11  24                Drone        Televisions and Displays     4449.99
# ...

# %%
# Question 1
display('info', Items.info)
display('describe', Items.describe)
display('describe_transpose', Items.describe().transpose())
display('median', Items.median)
display('head', Items.head(5))
# Out:
# 'head'
#    id           item_name                item_category  item_price  \
# 0  26       Action Camera        Photography Equipment     2694.25
# 1  37  Antivirus Software                     Software     4186.62
# 2  11      Blu-Ray Player  Video Players and Recorders     3382.86
# 3  25           Camcorder        Photography Equipment      860.01
# 4   7              Camera        Photography Equipment     2366.72
#
#    stock_quantity item_brand  item_availability
# 0             NaN       Bose              False
# 1             NaN        NaN              False
# 2           704.0       ASUS               True
# 3           870.0       Bose               True
# 4           458.0  Microsoft               True

# %%
customers = pd.read_csv("https://raw.githubusercontent.com/pythonai250824/14.05.2025/main/customers.csv")
customers
# Out:
#       id first_name  last_name  gender   age   nationallity joining_date  \
# 0      1      Eadie     Maffeo  Female  41.0         France   11/01/2022
# 1      2     Hammad  Brewerton    Male  56.0         Isreal   30/09/2022
# 2      3    Terrell       Bris    Male  43.0          India          NaN
# 3      4    Frannie   Morewood    Male  84.0         France   26/05/2021
# 4      5      Sophi      Fleet  Female  33.0         Sweden   19/07/2021
# ..   ...        ...        ...     ...   ...            ...          ...
# 495  496     Renado     Monard    Male  53.0          India          NaN
# 496  497     Kalina       Luno  Female  30.0          Italy   16/10/2022
# 497  498        Viv  Callander  Female  44.0         France   24/02/2021
# 498  499      Georg      Raper    Male  41.0        Germany   24/04/2022
# 499  500   Richardo   O'Criane    Male  32.0  United States   06/08/2021
#
#      phone_number                      email
# 0    534-341-9052        emaffeo0@smh.com.au
# ...

# %%
# Question 1
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            500 non-null    int64
#  1   first_name    494 non-null    object
#  2   last_name     494 non-null    object
#  3   gender        447 non-null    object
#  4   age           475 non-null    float64
#  5   nationallity  494 non-null    object
#  6   joining_date  439 non-null    object
#  7   phone_number  500 non-null    object
#  8   email         500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB

# %%
order_item = pd.read_csv("https://raw.githubusercontent.com/pythonai250824/14.05.2025/main/order_item.csv")
order_item
# Out:
#        id  order_id  item_id  quantity
# 0       1       337     10.0         2
# 1       2       430     27.0         6
# 2       3       430     36.0         2
# 3       4       508     46.0         1
# 4       5       229     27.0         2
# ..    ...       ...      ...       ...
# 995   996       594     24.0         2
# 996   997       330     32.0         8
# 997   998       472     10.0         3
# 998   999       222     29.0         1
# 999  1000       337     16.0         1
#
# [1000 rows x 4 columns]

# %%
# Question 1
order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1000 non-null   int64
#  1   order_id  1000 non-null   int64
#  2   item_id   960 non-null    float64
#  3   quantity  1000 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 31.4 KB

# %%
orders = pd.read_csv("https://raw.githubusercontent.com/pythonai250824/14.05.2025/main/orders.csv")
orders
# Out:
#      order_id  customer_id     delivery_address  delivery_days  order_date  \
# 0           1        477.0   576 Cordelia Place            2.0  2023-12-05
# 1           2         93.0       4664 6th Drive            4.0  2023-08-17
# 2           3        474.0       8766 4th Point            4.0  2023-02-25
# 3           4        333.0        31 Bonner Way            3.0  2023-02-04
# 4           5        436.0    20352 Shelley Way            5.0  2023-06-01
# ..        ...          ...                  ...            ...         ...
# 595       596        110.0       26 Hudson Lane            5.0  2023-10-30
# 596       597        209.0  37392 Sullivan Park            4.0  2023-08-23
# 597       598        480.0     1473 Ilene Drive            4.0  2023-09-11
# 598       599         72.0     2 Nancy Crossing            4.0  2023-02-09
# 599       600        169.0        545 Orin Lane            3.0  2023-02-16
#
#     payment_method order_source
# 0        GIFT_CARD      WEBSITE
# ...

# %%
# Question 1
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          600 non-null    int64
#  1   customer_id       555 non-null    float64
#  2   delivery_address  600 non-null    object
#  3   delivery_days     525 non-null    float64
#  4   order_date        600 non-null    object
#  5   payment_method    600 non-null    object
#  6   order_source      600 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 32.9+ KB

# %%
# Question 2
# 1. מחיר ממוצע של פריט
display('mean', Items['item_price'].mean())
# 5. הקנייה הכי זולה? הכי יקרה? ממוצע?
display('min', Items['item_price'].min())
display('max', Items['item_price'].max())
display('mean', Items['item_price'].mean())
# Out:
# 'mean'
# np.float64(2222.0825999999997)
# 'min'
# np.float64(241.54)
# 'max'
# np.float64(4471.27)
# 'mean'
# np.float64(2222.0825999999997)

# %%
# חקירת גרפים
# 1. פילוג לקוחות לפי מגדר

By_gender =['Female', 'Male', 'Non-binary', 'Female', 'Bigender']
gender_count ={'Female': By_gender.count('Female'),
                'Male': By_gender.count('Male'),
                'Non-binary': By_gender.count('Non-binary'),
                'Bigender': By_gender.count('Bigender')}

customers.dropna(subset=['gender'], inplace=True)
plt.figure(figsize=(8, 5))
plt.bar(gender_count.keys(), gender_count.values(), color=['pink', 'red', 'blue', 'silver'])
plt.title('Female v male gender')
plt.show()

# %%
#3. היסטוגרמת פילוג לקוחות לפי גיל

plt.figure(figsize=(12,4)) 
sns.displot(data=customers, x='age', bins=30,  kde=True) 
plt.title('Customer distribution histogram by age')
plt.ylabel('Customers')
plt.show()

# %%
# Question 3
1.ב-מוחקת שורות המכילות ערכים חסרים
2.א-מחזיר את שם העיר שמופיעה הכ הרבה
3.ב-מחליף את ערכי העמודה 
4.ג-בוחר 5 אקראיות
5.ג-ממלא ערכים חסרים בעמודה אם 0
6.ג-מוחקת שורות כפולות
7.ד-מחזיר את 3 הערכים הגדולים
8.ב-מחזיר א מספר ההופעות של כל ערך בעמודה
9.ג-יוצר סדרה בוליאנית 
10.א-מחלק טבלה לפי קטגוריה ומחשב ממוצע לעמודות

# %%
customers['gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 495      Male
# 496    Female
# 497    Female
# 498      Male
# 499      Male
# Name: gender, Length: 447, dtype: object>
